# %%
# Out:
# ...
#                                               0.0/321.3 kB ? eta -:--:--
#      -                                        10.2/321.3 kB ? eta -:--:--
#      --                                    20.5/321.3 kB 320.0 kB/s eta 0:00:01
#      ---                                   30.7/321.3 kB 259.2 kB/s eta 0:00:02
#      ---                                   30.7/321.3 kB 259.2 kB/s eta 0:00:02
#      ---                                   30.7/321.3 kB 259.2 kB/s eta 0:00:02
#      ---                                   30.7/321.3 kB 259.2 kB/s eta 0:00:02
#      ----                                  41.0/321.3 kB 122.9 kB/s eta 0:00:03
#      -----                                 51.2/321.3 kB 145.2 kB/s eta 0:00:02
#      -----                                 51.2/321.3 kB 145.2 kB/s eta 0:00:02
#      ---------                             81.9/321.3 kB 191.1 kB/s eta 0:00:02
#      ---------                             81.9/321.3 kB 191.1 kB/s eta 0:00:02
# ...

# %%
# Out:
# 🚀 Récupération des données du 2025-02-09 au 2026-02-09
# Interval: 15m
# ...
#
# 📈 Traitement de BTCUSDT...
# 📊 BTCUSDT: 1000 candles récupérées (Total: 1000)
# 📊 BTCUSDT: 1000 candles récupérées (Total: 2000)
# 📊 BTCUSDT: 1000 candles récupérées (Total: 3000)
# 📊 BTCUSDT: 1000 candles récupérées (Total: 4000)
# 📊 BTCUSDT: 1000 candles récupérées (Total: 5000)
# 📊 BTCUSDT: 1000 candles récupérées (Total: 6000)
# 📊 BTCUSDT: 1000 candles récupérées (Total: 7000)
# 📊 BTCUSDT: 1000 candles récupérées (Total: 8000)
# 📊 BTCUSDT: 1000 candles récupérées (Total: 9000)
# 📊 BTCUSDT: 1000 candles récupérées (Total: 10000)
# 📊 BTCUSDT: 1000 candles récupérées (Total: 11000)
# 📊 BTCUSDT: 1000 candles récupérées (Total: 12000)
# 📊 BTCUSDT: 1000 candles récupérées (Total: 13000)
# 📊 BTCUSDT: 1000 candles récupérées (Total: 14000)
# 📊 BTCUSDT: 1000 candles récupérées (Total: 15000)
# 📊 BTCUSDT: 1000 candles récupérées (Total: 16000)
# 📊 BTCUSDT: 1000 candles récupérées (Total: 17000)
# ...
